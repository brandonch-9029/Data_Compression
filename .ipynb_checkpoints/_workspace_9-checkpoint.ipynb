# %% [markdown]
# # Workspace for Data Compression Tasks, Block 9
# ## Imports

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
from implementations import audio

# %% [markdown]
# ## Task
#
# - plot the Bark data
# - plot Bark modelling function given by
#     - `audio.<schroeder>`,
#     - `audio.<terhardt>`,
#     - `audio.<zwicker>`,
#     - `audio.<traunmuller>`,
#     - (with thanks to A. Lerch (see the repo).

# %%
bark_data = audio.bark_data

# %%
bark_data
# Out:
#     Bark  Lower    Mid  Upper  Bandwidth
# 0      1      0     50    100        100
# 1      2    100    150    200        100
# 2      3    200    250    300        100
# 3      4    300    350    400        100
# 4      5    400    450    510        110
# 5      6    510    570    630        120
# 6      7    630    700    770        140
# 7      8    770    840    920        150
# 8      9    920   1000   1080        160
# 9     10   1080   1170   1270        190
# 10    11   1270   1370   1480        210
# 11    12   1480   1600   1720        240
# 12    13   1720   1850   2000        280
# 13    14   2000   2150   2320        320
# 14    15   2320   2500   2700        380
# 15    16   2700   2900   3150        450
# 16    17   3150   3400   3700        550
# 17    18   3700   4000   4400        700
# 18    19   4400   4800   5300        900
# 19    20   5300   5800   6400       1100
# 20    21   6400   7000   7700       1300
# 21    22   7700   8500   9500       1800
# 22    23   9500  10500  12000       2500
# 23    24  12000  13500  15500       3500

# %%
fig, ax = plt.subplots()
ax.scatter(bark_data["Bark"], bark_data["Bandwidth"])

# %% [markdown]
# ## Experimentation
#
# - Remember creating signals and using ipython's `Audio` functionality to hear them back (block 2)?
# - Now we'll do that, alongside noise, and combine them.
# - Play around with the frequency and amplitude of the signal, and with the "amount" of noise

# %%
from IPython.display import Audio

# %%
import numpy as np
sr = 22050 # sample rate
T = 1.0    # seconds
hz = 220
time_array = np.linspace(0, T, int(T * sr))

# %%
amp = 1/2
multiplier = 1/2
one_tone = amp * np.sin(2 * np.pi * multiplier * hz * time_array)
Audio(one_tone, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
noise = np.random.normal(0, 1, int(T * sr)) / 4

# %%
Audio(noise, rate=sr)

# %%
Audio(one_tone + (noise * 50), rate=sr)

# %% [markdown]
# ## Task
#
# - Explore the above (creating signals and noise)
# - Note your limits (when do you stop hearing the signal?).
# - (Think about or) Write a function that models whether you expect to hear it.
# - See how well your function matches your experience.

# %% [markdown]
# ## Reference

# %%
audio.plot_bark()

# %%
audio.plot_bark_models()

# %%
audio.plot_hearing_threshold()
